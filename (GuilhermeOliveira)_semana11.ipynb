# %% [markdown]
# <a href="https://colab.research.google.com/github/Guioliveiraa/qui/blob/main/(GuilhermeOliveira)_semana11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
arq_csv = "https://dados.ufs.br/dataset/cursos/resource/cur-csv-cursos-da-ufs/download/cur-csv-cursos-da-ufs.csv"

# %%
df_arq = pd.read_csv (arq_csv)

# %%
df_arq
# Out:
#               nome  ... alunos_concluidos
# 0    ADMINISTRAÇÃO  ...               698
# 1    ADMINISTRAÇÃO  ...                 1
# 2    ADMINISTRAÇÃO  ...               791
# 3    ADMINISTRAÇÃO  ...                 1
# 4    ADMINISTRAÇÃO  ...               156
# ..             ...  ...               ...
# 397        TURISMO  ...               161
# 398      ZOOTECNIA  ...                 0
# 399      ZOOTECNIA  ...                88
# 400      ZOOTECNIA  ...                37
# 401      ZOOTECNIA  ...               159
#
# [402 rows x 21 columns]

# %%
df_arq ["alunos_ativos"].max()
# Out:
# 554

# %% [markdown]
# CURSOS COM ALUNOS ATIVOS MAIOR QUE 100

# %%
df_arq [df_arq ["alunos_ativos"] > 100]
# Out:
#                     nome  ... alunos_concluidos
# 0          ADMINISTRAÇÃO  ...               698
# 3          ADMINISTRAÇÃO  ...                 1
# 4          ADMINISTRAÇÃO  ...               156
# 11         AGROINDUSTRIA  ...                26
# 16           ARQUEOLOGIA  ...               169
# ..                   ...  ...               ...
# 395               TEATRO  ...                61
# 396  TERAPIA OCUPACIONAL  ...               148
# 397              TURISMO  ...               161
# 400            ZOOTECNIA  ...                37
# 401            ZOOTECNIA  ...               159
#
# [111 rows x 21 columns]

# %% [markdown]
# CURSOS NOTURNOS

# %%
df_arq [df_arq ["turno"] == "Noturno"]
# Out:
#                                nome  ... alunos_concluidos
# 0                     ADMINISTRAÇÃO  ...               698
# 4                     ADMINISTRAÇÃO  ...               156
# 21   BIBLIOTECONOMIA E DOCUMENTAÇÃO  ...               204
# 41               CIÊNCIAS ATUARIAIS  ...                57
# 53              CIÊNCIAS BIOLÓGICAS  ...               277
# 57               CIÊNCIAS CONTÁBEIS  ...               283
# 58               CIÊNCIAS CONTÁBEIS  ...              1432
# 60             CIÊNCIAS DA RELIGIÃO  ...                51
# 64              CIÊNCIAS ECONÔMICAS  ...               475
# 87                            DANÇA  ...               117
# 91                   DESIGN GRÁFICO  ...                91
# 94                          DIREITO  ...              1149
# 151                     ESTATÍSTICA  ...               140
# 159                       FILOSOFIA  ...               333
# 166                          FÍSICA  ...               294
# ...

# %% [markdown]
# CURSOS NOTURNOS COM NUMERO DE ALUNOS MAIOR QUE 100

# %%
df_arq [df_arq ["alunos_ativos"] > 100 ] [df_arq ["turno"] == "Noturno"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                nome  ... alunos_concluidos
# 0                     ADMINISTRAÇÃO  ...               698
# 4                     ADMINISTRAÇÃO  ...               156
# 21   BIBLIOTECONOMIA E DOCUMENTAÇÃO  ...               204
# 41               CIÊNCIAS ATUARIAIS  ...                57
# 53              CIÊNCIAS BIOLÓGICAS  ...               277
# 57               CIÊNCIAS CONTÁBEIS  ...               283
# 58               CIÊNCIAS CONTÁBEIS  ...              1432
# 60             CIÊNCIAS DA RELIGIÃO  ...                51
# 64              CIÊNCIAS ECONÔMICAS  ...               475
# 91                   DESIGN GRÁFICO  ...                91
# 94                          DIREITO  ...              1149
# 151                     ESTATÍSTICA  ...               140
# ...

# %% [markdown]
# CURSOS VESPERTINOS COM NUMERO DE ALUNOS MAIOR QUE 100

# %%
df_arq [df_arq ["turno"] == "Vespertino"][df_arq ["alunos_ativos"] > 100 ]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                     nome  ... alunos_concluidos
# 3                          ADMINISTRAÇÃO  ...                 1
# 16                           ARQUEOLOGIA  ...               169
# 19                         ARTES VISUAIS  ...               267
# 33                 CIÊNCIA DA COMPUTAÇÃO  ...               525
# 54                   CIÊNCIAS BIOLÓGICAS  ...               359
# 55                   CIÊNCIAS BIOLÓGICAS  ...               502
# 65                   CIÊNCIAS ECONÔMICAS  ...               546
# 71                      CIÊNCIAS SOCIAIS  ...               207
# 73                  CINEMA E AUDIOVISUAL  ...                43
# 96                               DIREITO  ...              1258
# 109                      EDUCAÇÃO FÍSICA  ...               245
# ...

# %%
df_arq [df_arq ["turno"] == "Vespertino"]
# Out:
#                                     nome  ... alunos_concluidos
# 3                          ADMINISTRAÇÃO  ...                 1
# 16                           ARQUEOLOGIA  ...               169
# 19                         ARTES VISUAIS  ...               267
# 33                 CIÊNCIA DA COMPUTAÇÃO  ...               525
# 54                   CIÊNCIAS BIOLÓGICAS  ...               359
# 55                   CIÊNCIAS BIOLÓGICAS  ...               502
# 65                   CIÊNCIAS ECONÔMICAS  ...               546
# 71                      CIÊNCIAS SOCIAIS  ...               207
# 72                      CIÊNCIAS SOCIAIS  ...               336
# 73                  CINEMA E AUDIOVISUAL  ...                43
# 80                    COMUNICAÇÃO SOCIAL  ...               208
# 81                    COMUNICAÇÃO SOCIAL  ...                89
# 83                    COMUNICAÇÃO SOCIAL  ...               161
# 96                               DIREITO  ...              1258
# ...

# %% [markdown]
# CURSOS BACHARELADO

# %%
df_arq [df_arq ["grau_academico"] == "Bacharelado"]
# Out:
#                        nome  ... alunos_concluidos
# 0             ADMINISTRAÇÃO  ...               698
# 2             ADMINISTRAÇÃO  ...               791
# 3             ADMINISTRAÇÃO  ...                 1
# 4             ADMINISTRAÇÃO  ...               156
# 6     ADMINISTRAÇÃO PÚBLICA  ...               115
# ..                      ...  ...               ...
# 391  SISTEMAS DE INFORMAÇÃO  ...                74
# 396     TERAPIA OCUPACIONAL  ...               148
# 397                 TURISMO  ...               161
# 400               ZOOTECNIA  ...                37
# 401               ZOOTECNIA  ...               159
#
# [101 rows x 21 columns]

# %% [markdown]
# CURSOS DE LICENCIATURA PLENA

# %%
df_arq [df_arq ["grau_academico"] == "Licenciatura Plena"]
# Out:
#                     nome  ... alunos_concluidos
# 1          ADMINISTRAÇÃO  ...                 1
# 19         ARTES VISUAIS  ...               267
# 42   CIÊNCIAS BIOLÓGICAS  ...                 9
# 43   CIÊNCIAS BIOLÓGICAS  ...                 2
# 44   CIÊNCIAS BIOLÓGICAS  ...                 3
# ..                   ...  ...               ...
# 366              QUÍMICA  ...                 0
# 367              QUÍMICA  ...                 1
# 368              QUÍMICA  ...                 1
# 394               TEATRO  ...                37
# 395               TEATRO  ...                61
#
# [165 rows x 21 columns]

# %% [markdown]
# GUILHERME OLIVEIRA TORRES GOMES 0050016114
#
#
#
#
# Existem mais cursos de Licenciatura do que de bacharelado
#
# O numero maximo de alunos ativos em um curso é de 554
